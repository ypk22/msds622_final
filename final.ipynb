# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go

# %%
df = pd.read_excel('total.xlsx')

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
set(df['country_txt'].values)
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia-Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Czechoslovakia',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'East Germany (GDR)',
#  'East Timor',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Falkland Islands',
#  'Fiji',
#  'Finland',
#  'France',
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaT       58
# 1  197000000002   1970       0     0        NaN         0        NaT      130
# 2  197001000001   1970       1     0        NaN         0        NaT      160
# 3  197001000002   1970       1     0        NaN         0        NaT       78
# 4  197001000003   1970       1     0        NaN         0        NaT      101
#
#           country_txt  region   ...    addnotes scite1 scite2  scite3  \
# 0  Dominican Republic       2   ...         NaN    NaN    NaN     NaN
# 1              Mexico       1   ...         NaN    NaN    NaN     NaN
# 2         Philippines       5   ...         NaN    NaN    NaN     NaN
# 3              Greece       8   ...         NaN    NaN    NaN     NaN
# 4               Japan       4   ...         NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.groupby('country_txt').count()
# Out:
#                           eventid  iyear  imonth   iday  approxdate  extended  \
# country_txt
# Afghanistan                 12731  12731   12731  12731        1099     12731
# Albania                        80     80      80     80           0        80
# Algeria                      2743   2743    2743   2743          77      2743
# Andorra                         1      1       1      1           0         1
# Angola                        499    499     499    499           3       499
# Antigua and Barbuda             1      1       1      1           0         1
# Argentina                     815    815     815    815           1       815
# Armenia                        24     24      24     24           0        24
# Australia                     114    114     114    114           0       114
# Austria                       115    115     115    115           2       115
# Azerbaijan                     49     49      49     49           1        49
# ...

# %%
df[df['country_txt'] == 'United States']
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 5       197001010002   1970       1     1                  NaN         0
# 7       197001020002   1970       1     2                  NaN         0
# 8       197001020003   1970       1     2                  NaN         0
# 9       197001030001   1970       1     3                  NaN         0
# 10      197001050001   1970       1     1                  NaN         0
# 11      197001060001   1970       1     6                  NaN         0
# 13      197001090001   1970       1     9                  NaN         0
# 14      197001090002   1970       1     9                  NaN         0
# 17      197001120001   1970       1    12                  NaN         0
# 18      197001120002   1970       1    12                  NaN         0
# 19      197001130001   1970       1    13                  NaN         0
# 20      197001140001   1970       1    14                  NaN         0
# ...

# %% [markdown]
# ## Histogram

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

# df_1970 = df[df['iyear'] == 1970]
# df_2017 = df[df['iyear']]
df_hist = df.groupby('iyear').count()

# %%
df_hist
# Out:
#        eventid  imonth   iday  approxdate  extended  resolution  country  \
# iyear
# 1970       651     651    651           6       651          29      651
# 1971       471     471    471           6       471           7      471
# 1972       568     568    568           2       568           8      568
# 1973       473     473    473           0       473          30      473
# 1974       581     581    581           2       581          19      581
# 1975       740     740    740           0       740          25      740
# 1976       923     923    923           0       923          27      923
# 1977      1319    1319   1319           0      1319          36     1319
# 1978      1526    1526   1526           0      1526          33     1526
# 1979      2662    2662   2662           1      2662          45     2662
# 1980      2662    2662   2662           3      2662          32     2662
# 1981      2586    2586   2586           1      2586          40     2586
# ...

# %%
df_hist.index.values
# Out:
# array(['Australasia & Oceania', 'Central America & Caribbean',
#        'Central Asia', 'East Asia', 'Eastern Europe',
#        'Middle East & North Africa', 'North America', 'South America',
#        'South Asia', 'Southeast Asia', 'Sub-Saharan Africa',
#        'Western Europe'], dtype=object)

# %%
y
# Out:
# array([  282, 10344,   563,   802,  5144, 50474,  3456, 18978, 44974,
#        12485, 17550, 16639])

# %%
x = df['iyear']
# y = df_hist.eventid.values

# x = ["Apples","Apples","Apples","Oranges", "Bananas"]

trace0 = go.Histogram(
    histnorm='probability',
    x=x,
#     y=y
)
# trace1 = go.Histogram(
#     x=x1
# )
data = [trace0]
layout = go.Layout(
    xaxis=dict(
        title='Year',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=10,
            color='black'
        ),
    ),
    yaxis=dict(
        title='Proportion of Acts of Terror',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
    tickfont=dict(
#             family='Old Standard TT, serif',
            size=10,
            color='black'
        ),
    ),
    title=go.layout.Title(
        text='Proportion of Acts of Terror in the World by from 1970-2017',
        xref='paper',
        x=0
    ),
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='normalized histogram')

# py.iplot(fig, filename='stacked histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~paulkorean/90.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Bar

# %%
df_cac = df[df['region_txt'] == 'Central America & Caribbean']
df_na = df[df['region_txt'] == 'North America']
df_sea = df[df['region_txt'] == 'Southeast Asia']
df_we = df[df['region_txt'] == 'Western Europe']
df_ea = df[df['region_txt'] == 'East Asia']
df_sa = df[df['region_txt'] == 'South America']
df_ee = df[df['region_txt'] == 'Eastern Europe']
df_ssa = df[df['region_txt'] == 'Sub-Saharan Africa']
df_mena = df[df['region_txt'] == 'Middle East & North Africa']
df_ac = df[df['region_txt'] == 'Australasia & Oceania']
df_sas = df[df['region_txt'] == 'South Asia']
df_ca = df[df['region_txt'] == 'Central Asia']

# %%
df_cac_ct = df_cac.groupby('country_txt').count()
df_na_ct = df_na.groupby('country_txt').count()
df_sea_ct = df_sea.groupby('country_txt').count()
df_we_ct = df_we.groupby('country_txt').count()
df_ea_ct = df_ea.groupby('country_txt').count()
df_sa_ct = df_sa.groupby('country_txt').count()
df_ee_ct = df_ee.groupby('country_txt').count()
df_ssa_ct = df_ssa.groupby('country_txt').count()
df_mena_ct = df_mena.groupby('country_txt').count()
df_ac_ct = df_ac.groupby('country_txt').count()
df_sas_ct = df_sas.groupby('country_txt').count()
df_ca_ct = df_ca.groupby('country_txt').count()

# %%
df_na_ct
# Out:
#                eventid  iyear  imonth  iday  approxdate  extended  resolution  \
# country_txt
# Canada              96     96      96    96           1        96           2
# Mexico             524    524     524   524           3       524          27
# United States     2836   2836    2836  2836          37      2836          12
#
#                country  region  region_txt   ...     addnotes  scite1  scite2  \
# country_txt                                  ...
# Canada              96      96          96   ...           10      60      52
# Mexico             524     524         524   ...           58     123      84
# United States     2836    2836        2836   ...         1238    1783    1617
#
#                scite3  dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY  related
# country_txt
# Canada             36        96       96        96        96       96        8
# Mexico             43       524      524       524       524      524       47
# ...

# %%
set(df['weapsubtype1_txt'].values)
# Out:
# {'Arson/Fire',
#  'Automatic or Semi-Automatic Rifle',
#  'Blunt Object',
#  'Dynamite/TNT',
#  'Explosive',
#  'Gasoline or Alcohol',
#  'Grenade',
#  'Handgun',
#  'Hands, Feet, Fists',
#  'Knife or Other Sharp Object',
#  'Landmine',
#  'Letter Bomb',
#  'Molotov Cocktail/Petrol Bomb',
#  'Other Explosive Type',
#  'Other Gun Type',
#  'Pipe Bomb',
#  'Poisoning',
#  'Pressure Trigger',
#  'Projectile (rockets, mortars, RPGs, etc.)',
#  'Remote Trigger',
#  'Rifle/Shotgun (non-automatic)',
#  'Rope or Other Strangling Device',
#  'Sticky Bomb',
#  'Suffocation',
#  'Suicide (carried bodily by human being)',
#  'Time Fuse',
#  'Unknown Explosive Type',
#  'Unknown Gun Type',
#  'Unknown Weapon Type',
#  'Vehicle',
#  nan}

# %%
df_weap = df.groupby('weaptype1_txt').count()

# %%
weap_short = df_weap.index.values

# %%
weap_short[1] = 'Auto/Semi-Auto Rifle'

# %%
weap_short[18] = 'Projectile'

# %%
weap_short
# Out:
# array(['Biological', 'Chemical', 'Explosives', 'Fake Weapons', 'Firearms',
#        'Incendiary', 'Melee', 'Other', 'Radiological',
#        'Sabotage Equipment', 'Unknown',
#        'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)'],
#       dtype=object)

# %%
weap_short[20] = 'Non-Auto Gun'
weap_short[21] = 'Strangling Device'
weap_short[24] = 'Suicide'
weap_short[9] = 'Sharp Object'
weap_short[26] = 'Unknown Explosive'
weap_short[27] = 'Unknown Gun'
weap_short[28] = 'Unknown Weapon'
weap_short[12] = 'Molotov Cocktail'

# %%
weap_short[-1] = 'Vehicle'

# %%
df_usa = df[df['country_txt'] == 'United States']

# %%
df_usa_weap = df_usa.groupby('weaptype1_txt').count()

# %%
x = weap_short
y = df_weap.region.values
y2 = df_usa_weap.region.values
trace1 = go.Bar(
            x=x,
            y=y,
    name = 'World'
    )
trace2 = go.Bar(
    x=x,
    y=y2,
    name='USA'
)
layout = go.Layout(
    xaxis=dict(tickangle=-45,
        title='Weapon Type',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=10,
            color='black'
        ),
    ),
    yaxis=dict(
        title='Number of Acts of Terrorism',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
    ),
    title=go.layout.Title(
        text='Number of Acts of Terrorism by Weapon Type, World vs. USA, 1970-2017',
        xref='paper',
        x=0
    ),
#     barmode='group',
)
data = [trace1, trace2]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='weapon bar')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~paulkorean/92.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Box Plot

# %%
df.groupby('region_txt').sum().nkill+df.groupby('region_txt').sum().nwound
# Out:
# region_txt
# Australasia & Oceania             410.0
# Central America & Caribbean     37699.0
# Central Asia                     3009.0
# East Asia                       10365.0
# Eastern Europe                  19460.0
# Middle East & North Africa     351950.0
# North America                   26447.0
# South America                   45553.0
# South Asia                     242679.0
# Southeast Asia                  41896.0
# Sub-Saharan Africa             131243.0
# Western Europe                  25026.0
# dtype: float64

# %%
y1
# Out:
# array([0., 0., 0., ..., 1., 0., 2.])

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np
df_cac = df[df['region_txt'] == 'Central America & Caribbean']
df_na = df[df['region_txt'] == 'North America']
df_sea = df[df['region_txt'] == 'Southeast Asia']
df_we = df[df['region_txt'] == 'Western Europe']
df_ea = df[df['region_txt'] == 'East Asia']
df_sa = df[df['region_txt'] == 'South America']
df_ee = df[df['region_txt'] == 'Eastern Europe']
df_ssa = df[df['region_txt'] == 'Sub-Saharan Africa']
df_mena = df[df['region_txt'] == 'Middle East & North Africa']
df_ac = df[df['region_txt'] == 'Australasia & Oceania']
df_sas = df[df['region_txt'] == 'South Asia']
df_ca = df[df['region_txt'] == 'Central Asia']

y0 = df_cac['nkill'].values+df_cac['nwound'].values
y1 = df_na['nkill'].values+df_na['nwound'].values
y2 = df_sea['nkill'].values+df_sea['nwound'].values
y3 = df_we['nkill'].values+df_we['nwound'].values
y4 = df_ea['nkill'].values+df_ea['nwound'].values
y5 = df_sa['nkill'].values+df_sa['nwound'].values
y6 = df_ee['nkill'].values+df_ee['nwound'].values
y7 = df_ssa['nkill'].values+df_ssa['nwound'].values
y8 = df_mena['nkill'].values+df_mena['nwound'].values
y9 = df_ac['nkill'].values+df_ac['nwound'].values
y10 = df_sas['nkill'].values+df_sas['nwound'].values
y11 = df_ca['nkill'].values+df_ca['nwound'].values

trace0 = go.Box(
    y=np.log(y0),
    name = 'Central America & Caribbean',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=np.log(y1),
    name = 'North America',
    marker = dict(
        color = 'rgb(0, 128, 128)',
    )
)
trace2 = go.Box(
    y=np.log(y2),
    name = 'Southeast Asia',
    marker = dict(
        color = 'rgb(39, 80, 60)',
    )
)

trace3 = go.Box(
    y=np.log(y3),
    name = 'Western Europe',
    marker = dict(
        color = 'rgb(200, 128, 128)',
    )
)

trace4 = go.Box(
    y=np.log(y4),
    name = 'East Asia',
    marker = dict(
        color = 'rgb(100, 208, 100)',
    )
)

trace5 = go.Box(
    y=np.log(y5),
    name = 'South America',
    marker = dict(
        color = 'rgb(200, 20, 70)',
    )
)

trace6 = go.Box(
    y=np.log(y6),
    name = 'Eastern Europe',
    marker = dict(
        color = 'rgb(30, 0, 200)',
    )
)

trace7 = go.Box(
    y=np.log(y7),
    name = 'Sub-Saharan Africa',
    marker = dict(
        color = 'rgb(70, 170, 100)',
    )
)

trace8 = go.Box(
    y=np.log(y8),
    name = 'Middle East & North Africa',
    marker = dict(
        color = 'rgb(40, 40, 40)',
    )
)

trace9 = go.Box(
    y=np.log(y9),
    name = 'Australasia & Oceania',
    marker = dict(
        color = 'rgb(180, 230, 90)',
    )
)

trace10 = go.Box(
    y=np.log(y10),
    name = 'South Asia',
    marker = dict(
        color = 'rgb(128, 0, 180)',
    )
)

trace11= go.Box(
    y=np.log(y11),
    name = 'Central Asia',
    marker = dict(
        color = 'rgb(200, 80, 250)',
    )
)

layout = go.Layout(
    xaxis=dict(tickangle=-35,
        title='Region',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=9,
            color='black'
        ),
    ),
    yaxis=dict(
        title='Casualties (natural log transformed)',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
    ),
    title=go.layout.Title(
        text='Casualties per Geographic Region, Natural log Transformed, 1970-2017',
        xref='paper',
        x=0
    ),
#     barmode='group',
)
data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, trace11]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename = 'box')
# Out:
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:54: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:62: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:78: RuntimeWarning:
#
# divide by zero encountered in log
#
# ...

# %% [markdown]
# ## Scatter

# %%
len(set(df.gname.values))
# Out:
# 3537

# %%
group = df.groupby('gname').count()

# %%
group.region.values
# Out:
# array([10,  4,  1, ...,  1,  1,  1])

# %%
max(np.lgroup.region.values)
# Out:
# 82782

# %%
import plotly.graph_objs as go
import plotly.plotly as py

import numpy as np

trace1 = go.Scatter(
    x = np.log(df['nwound']),
    y = np.log(df['nkill']),
    mode='markers',
    marker=dict(
        size=6,
        color = df['region'], #set color equal to a variable
        colorscale='Viridis',
#         showscale=True
    ),
    text = df['region_txt']
)

layout = go.Layout(
    xaxis=dict(
        title='Number of Injuries (natural log transformed)',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
    ),
    yaxis=dict(
        title='Number of Fatalities (natural log transformed)',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
    ),
    title=go.layout.Title(
        text='Number of Fatalities vs. Injuries, log transformed, in Terrorist Acts in the World, Colored by Region, 1970-2017',
        xref='paper',
        x=0
    ),
#     barmode='group',
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='scatter-plot-with-colorscale')
# Out:
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning:
#
# divide by zero encountered in log
#
# /Users/paulkim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning:
#
# divide by zero encountered in log
# The draw time for this plot will be slow for all clients.
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/2.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Bubble Map

# %%
len(set(df[df['country_txt'] == 'United States'].gname.values))
# Out:
# 234

# %%
np.argmax(df[df['country_txt'] == 'United States']['nkill'].values)
# Out:
# 272

# %%
df2 = df.copy()

# %%
df2.fillna(value = {'nkill': 0, 'nwound': 0}, inplace=True)

# %%
df2 = df2[df2['country_txt'] == 'United States']

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_us_cities.csv')
# df.head()

df2['text'] = df2['gname'] + ', ' + df2['city'] + ', ' + 'Casualties: ' + (df2['nkill'] + df2['nwound']).astype(str) + ', ' + df2['iyear'].astype(str)
# limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","lightgrey"]
cities = []
scale = 5000

data = [
    go.Scattermapbox(
        lat=df[df['country_txt'] == 'United States'].latitude,
        lon=df[df['country_txt'] == 'United States'].longitude,
        mode='markers',
        name = 'Terrorist Attack',
        marker=go.scattermapbox.Marker(
            size=np.log(df2['nkill'] + df2['nwound']+.01) + 8,
#             color=df.price,
#             colorscale = scl,
            opacity=0.7,
#             showscale = True,
#             cmax = df['price'].max()
#             symbol = 'circle'
        ),
        text=df2.text,
        hoverinfo='text'
    ),
    ]

layout = go.Layout(
    title='Terrorist Attacks in the US, Sized by # of Casualties, 1970-2017',
    autosize=True,
    hovermode='closest',
    showlegend=True,
    mapbox=go.layout.Mapbox(
        bearing=0,
        center=go.layout.mapbox.Center(
            lat=38.2676,
            lon=-97.5164
        ),
        pitch=0,
        zoom=3,
        style='dark'
    ),
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Price per description length')
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~pkdong/0 or inside your plot.ly account where it is named 'Price per description length'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Choropleth

# %%
df.groupby('country_txt').count()
# Out:
#                           eventid  iyear  imonth   iday  approxdate  extended  \
# country_txt
# Afghanistan                 12731  12731   12731  12731        1099     12731
# Albania                        80     80      80     80           0        80
# Algeria                      2743   2743    2743   2743          77      2743
# Andorra                         1      1       1      1           0         1
# Angola                        499    499     499    499           3       499
# Antigua and Barbuda             1      1       1      1           0         1
# Argentina                     815    815     815    815           1       815
# Armenia                        24     24      24     24           0        24
# Australia                     114    114     114    114           0       114
# Austria                       115    115     115    115           2       115
# Azerbaijan                     49     49      49     49           1        49
# ...

# %%
list(set(df['country_txt']))
# Out:
# ['Barbados',
#  'Ivory Coast',
#  'Croatia',
#  'Ukraine',
#  'North Korea',
#  'Serbia',
#  'Sri Lanka',
#  'Bosnia-Herzegovina',
#  'Estonia',
#  'Cyprus',
#  'St. Lucia',
#  'Afghanistan',
#  'Latvia',
#  'Serbia-Montenegro',
#  'South Africa',
#  'Yemen',
#  'Belize',
#  'Jordan',
#  'Bahrain',
#  'Soviet Union',
#  'Argentina',
#  'Iraq',
#  'Luxembourg',
#  'Finland',
#  'Trinidad and Tobago',
#  'Cambodia',
#  'Sierra Leone',
#  'Honduras',
#  'Gambia',
#  'Poland',
#  'Martinique',
#  'Madagascar',
#  'North Yemen',
#  'Hungary',
#  'Bahamas',
#  'Peru',
#  'Uruguay',
#  'Hong Kong',
#  "People's Republic of the Congo",
#  'Haiti',
#  'Seychelles',
#  'Sweden',
#  'Ethiopia',
#  'Ecuador',
#  'Albania',
#  'Morocco',
#  'Romania',
#  'Swaziland',
#  'Czech Republic',
#  'Venezuela',
#  'Brunei',
#  'Lithuania',
#  'Ghana',
#  'Singapore',
#  'Malawi',
#  'Saudi Arabia',
#  'New Caledonia',
#  'Germany',
#  'East Timor',
#  'Moldova',
#  'Dominican Republic',
#  'Greece',
# ...

# %%
df.groupby('country_txt').count().index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Vietnam', 'Wallis and Futuna', 'West Bank and Gaza Strip',
#        'West Germany (FRG)', 'Western Sahara', 'Yemen', 'Yugoslavia', 'Zaire',
#        'Zambia', 'Zimbabwe'],
#       dtype='object', name='country_txt', length=205)

# %%
scl = [
    [0.0, 'rgb(0,255,0)'],
    [0.1, 'rgb(110,255,0)'],
    [0.25, 'rgb(160,255,0)'],
    [0.4, 'rgb(200,255,0)'],
    [0.6, 'rgb(255,200,0)'],
    [0.99, 'rgb(255,100,0)'],
    [1.0, 'rgb(255,0,0)']
]
data = dict (
    type = 'choropleth',
    locations = df.groupby('country_txt').count().index,
    locationmode='country names',
    colorscale = scl,
    z=df.groupby('country_txt').count().region)
layout = go.Layout(
    title='Number of Terrorist Attacks per Country, 1970-2017')

map = go.Figure(data=[data], layout = layout)
py.iplot(map, filename= 'terror_world')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/6.embed" height="525px" width="100%"></iframe>

# %%
df2002 = df[df['iyear'] <=2002]

# %%
scl = [
    [0.0, 'rgb(0,255,0)'],
    [0.2, 'rgb(110,255,0)'],
#     [0.4, 'rgb(160,255,0)'],
    [0.4, 'rgb(200,255,0)'],
    [0.6, 'rgb(255,200,0)'],
    [0.8, 'rgb(255,100,0)'],
    [1.0, 'rgb(255,0,0)']
]
data = dict (
    type = 'choropleth',
    locations = df2002.groupby('country_txt').count().index,
    locationmode='country names',
    colorscale = scl,
    z=df2002.groupby('country_txt').count().region)
layout = go.Layout(
    title='Number of Terrorist Attacks per Country, 1970-2002 (Pre-Iraq War)')

map = go.Figure(data=[data], layout = layout)
py.iplot(map, filename= 'terror_world')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/6.embed" height="525px" width="100%"></iframe>

# %%
df2017 = df[df['iyear'] > 2002]
scl = [
    [0.0, 'rgb(0,255,0)'],
    [0.1, 'rgb(110,255,0)'],
    [0.25, 'rgb(160,255,0)'],
    [0.4, 'rgb(200,255,0)'],
    [0.6, 'rgb(255,200,0)'],
    [0.99, 'rgb(255,100,0)'],
    [1.0, 'rgb(255,0,0)']
]
data = dict (
    type = 'choropleth',
    locations = df2017.groupby('country_txt').count().index,
    locationmode='country names',
    colorscale = scl,
    z=df2017.groupby('country_txt').count().region)
layout = go.Layout(
    title='Number of Terrorist Attacks per Country, 2003-2017 (Post-Iraq War)')

map = go.Figure(data=[data], layout = layout)
py.iplot(map, filename= 'terror_world')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/6.embed" height="525px" width="100%"></iframe>

# %%
df_rel = df.dropna(subset = ['related']).reset_index()

# %%
df_rel_us = df_rel[df_rel['country_txt'] == 'United States'].reset_index()

# %% [markdown]
# ## Connection Map

# %%
data
# Out:
# [Scattergeo({
#      'lat': [42.479999, [42.479999]],
#      'line': {'color': 'blue', 'width': 2},
#      'lon': [-96.413046, [-96.413046]],
#      'mode': 'lines'
#  }), Scattergeo({
#      'lat': [42.479999, [42.46634]],
#      'line': {'color': 'blue', 'width': 2},
#      'lon': [-96.413046, [-96.41405]],
#      'mode': 'lines'
#  }), Scattergeo({
#      'lat': [42.46634, [42.479999]],
#      'line': {'color': 'blue', 'width': 2},
#      'lon': [-96.41405, [-96.413046]],
#      'mode': 'lines'
#  }), Scattergeo({
#      'lat': [42.46634, [42.46634]], 'line': {'color': 'blue', 'width': 2}, 'lon': [-96.41405, [-96.41405]], 'mode': 'lines'
#  }), Scattergeo({
#      'lat': [40.697132, [40.697132]],
#      'line': {'color': 'blue', 'width': 2},
#      'lon': [-73.931351, [-73.931351]],
#      'mode': 'lines'
#  }), Scattergeo({
#      'lat': [40.697132, [40.697132]],
#      'line': {'color': 'blue', 'width': 2},
#      'lon': [-73.931351, [-73.931351]],
#      'mode': 'lines'
# ...

# %%
import requests

# %%
def get_boundingbox_country(country, output_as='center'):
    """
    get the bounding box of a country in EPSG4326 given a country name

    Parameters
    ----------
    country : str
        name of the country in english and lowercase
    output_as : 'str
        chose from 'boundingbox' or 'center'. 
         - 'boundingbox' for [latmin, latmax, lonmin, lonmax]
         - 'center' for [latcenter, loncenter]

    Returns
    -------
    output : list
        list with coordinates as str
    """
    # create url
    url = '{0}{1}{2}'.format('http://nominatim.openstreetmap.org/search?country=',
                             country,
                             '&format=json&polygon=0')
    response = requests.get(url).json()[0]

    # parse response to list
    if output_as == 'boundingbox':
        lst = response[output_as]
        output = [float(i) for i in lst]
    if output_as == 'center':
        lst = [response.get(key) for key in ['lat','lon']]
        output = [float(i) for i in lst]
    return output

# %%
3

# %%
natlcoor = []
for index, row in df_us.iterrows():
    try:
        natlcoor.append(get_boundingbox_country(row['natlty1_txt']))
    except:
        natlcoor.append(get_boundingbox_country('United States'))

# %%
natlcoor
# Out:
# [[39.7837304, -100.4458825],
#  [39.7837304, -100.4458825],
#  [39.7837304, -100.4458825],
#  [39.7837304, -100.4458825],
#  [39.7837304, -100.4458825],
#  [39.7837304, -100.4458825]]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

nyc_london = [go.Scattergeo(
    lat = [40.7127, 51.5072],
    lon = [-74.0059, 0.1275],
    mode = 'lines',
    line = go.scattergeo.Line(
        width = 2,
        color = 'blue',
    ),
)]

data = []
for i in range(len(df_rel_us.related)):
    for e in df_rel_us.related.iloc[i].split(','):
        try:
#             if df_rel_us.latitude.iloc[i] != df[df['eventid'] == int(e):
                data.append(
                    go.Scattergeo(
                        locationmode = 'USA-states',
                        lat = [df_rel_us.latitude.iloc[i], df[df['eventid'] == int(e)].latitude],
                        lon = [df_rel_us.longitude.iloc[i], df[df['eventid'] == int(e)].longitude],
                        mode = 'lines',
                        line = go.scattergeo.Line(
                            width = 1,
                            color = 'blue',
                    ),
        ))
        except ValueError:
                pass
            
# for i in range(len(df_flight_paths)):
#     flight_paths.append(
#         go.Scattergeo(
#             locationmode = 'USA-states',
#             lon = [df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i]],
#             lat = [df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i]],
#             mode = 'lines',
#             line = go.scattergeo.Line(
#                 width = 1,
#                 color = 'red',
#             ),
#             opacity = float(df_flight_paths['cnt'][i]) / float(df_flight_paths['cnt'].max()),
#         )
#     )

layout = go.Layout(
    title = go.layout.Title(
        text = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)'
    ),
    showlegend = False,
    geo = go.layout.Geo(
        scope = 'north america',
        projection = go.layout.geo.Projection(type = 'azimuthal equal area'),
        showland = True,
        landcolor = 'rgb(243, 243, 243)',
        countrycolor = 'rgb(204, 204, 204)',
    ),
)

fig = go.Figure(data = data, layout = layout)
py.iplot(fig, filename = 'd3-great-circle')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/14.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Heatmap

# %%
df_cac = df[df['region_txt'] == 'Central America & Caribbean']
df_na = df[df['region_txt'] == 'North America']
df_sea = df[df['region_txt'] == 'Southeast Asia']
df_we = df[df['region_txt'] == 'Western Europe']
df_ea = df[df['region_txt'] == 'East Asia']
df_sa = df[df['region_txt'] == 'South America']
df_ee = df[df['region_txt'] == 'Eastern Europe']
df_ssa = df[df['region_txt'] == 'Sub-Saharan Africa']
df_mena = df[df['region_txt'] == 'Middle East & North Africa']
df_ac = df[df['region_txt'] == 'Australasia & Oceania']
df_sas = df[df['region_txt'] == 'South Asia']
df_ca = df[df['region_txt'] == 'Central Asia']

# %%
df_cac_att = df_cac.groupby('attacktype1_txt').count()
df_na_att = df_na.groupby('attacktype1_txt').count()
df_sea_att = df_sea.groupby('attacktype1_txt').count()
df_we_att = df_we.groupby('attacktype1_txt').count()
df_ea_att = df_ea.groupby('attacktype1_txt').count()
df_sa_att = df_sa.groupby('attacktype1_txt').count()
df_ee_att = df_ee.groupby('attacktype1_txt').count()
df_ssa_att = df_ssa.groupby('attacktype1_txt').count()
df_mena_att = df_mena.groupby('attacktype1_txt').count()
# df_mena_att = df_mena.groupby('attacktype1_txt').count()
df_ac_att = df_ac.groupby('attacktype1_txt').count()
df_sas_att = df_sas.groupby('attacktype1_txt').count()
df_ca_att = df_ca.groupby('attacktype1_txt').count()

# %%
df_cac_att.eventid.values
# Out:
# array([4361, 1254, 3239,  403,   26,  187,  501,   19,  354])

# %%
attks = df_cac_att.index.values

# %%
attks[5] = 'Hostage (Barricade)'
attks[6] = 'Hostage (Kidnapping)'

# %%
trace = go.Heatmap(z=[df_cac_att.eventid.values, df_na_att.eventid.values, df_sea_att.eventid.values, 
                      df_we_att.eventid.values,
                     df_ea_att.eventid.values, df_sa_att.eventid.values, df_ee_att.eventid.values
                      , df_ssa_att.eventid.values,
                     df_mena_att.eventid.values, df_ac_att.eventid.values, df_sas_att.eventid.values, 
                      df_ca_att.eventid.values],
                   y=['C. Amer. & Caribbean', 'North America', 'Southeast Asia', 
                      'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
                      'Sub-Saharan Africa', 'M. East & N. Africa', 'Australasia & Oceania',
                      'South Asia', 'Central Asia'],
                   x=attks)

layout = go.Layout(
    xaxis=dict(tickangle=-35,
        title='Type of Attack',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=8,
            color='black'
        ),
    ),
    yaxis=dict(
        title='Region',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=7,
            color='black'
        ),
    ),
    title=go.layout.Title(
        text='Heatmap of Region and Type of Attack 1970-2017',
        xref='paper',
        x=0
    ),
#     barmode='group',
)

data=[trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='labelled-heatmap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/8.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Stacked Area Graph

# %%
gnames = set(df_usa['gname'].values)

# %%
gnames_b = []
for e in list(gnames):
    if 'Black' in e:
        gnames_b.append(e)
    elif 'black' in e:
        gnames_b.append(e)

# %%
gnames_j =

# %%
gnames_b = 'Black' in gnames

# %%
gnames_b
# Out:
# ['Black Afro Militant Movement',
#  'Black Liberation Army',
#  'Black September',
#  'Black Hebrew Israelites',
#  'Black American Moslems',
#  'Black Nationalists',
#  'Black Revolutionary Assault Team',
#  'Black Brigade (United States)',
#  'Black Muslims',
#  'Black Panthers']

# %%
df_usa_white.groupby('iyear').count().eventid,
# Out:
# (iyear
#  1970    34
#  1971    12
#  1972     1
#  1973     2
#  1975     3
#  1976     3
#  1977     2
#  1978     3
#  1979     5
#  1980    14
#  1981     3
#  1982     1
#  1983     1
#  1985     2
#  1990     1
#  1994     4
#  1995     2
#  1996     2
#  1997     1
#  1999     7
#  2003     1
#  2004     1
#  2006     1
#  2008     3
#  2009     1
#  2012     4
#  2014     3
#  2015     1
#  2016     3
#  2017    14
#  Name: eventid, dtype: int64,)

# %%
df_usa_white = df_usa[df_usa['gname'].isin(['Ku Klux Klan','Neo-Nazi extremists','White extremists',
                                            'Anti-Semitic extremists', 'United Aryan Empire'])]
df_usa_anti_arab = df_usa[df_usa['gname'].isin(['Anti-Arab extremists','Anti-Muslim extremists','Anti-Sikh extremists'
                         ])]
df_usa_black_lib = df_usa[df_usa['gname'].isin(gnames_b)]

# %%
df_usa

# %%
# Add original data
x=df.iyear.values

trace0 = dict(
    x=df_usa_white.groupby('iyear').count().index.values,
    y=df_usa_white.groupby('iyear').count().eventid,
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(131, 90, 241)'),
    stackgroup='one',
    name = 'White Extremism'
)
trace1 = dict(
    x=df_usa_anti_arab.groupby('iyear').count().index.values,
    y=df_usa_anti_arab.groupby('iyear').count().eventid,
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(111, 231, 219)'),
    stackgroup='one',
    name = 'Anti-Arab Extremism'
)
trace2 = dict(
    x=df_usa_black_lib.groupby('iyear').count().index.values,
    y=df_usa_black_lib.groupby('iyear').count().eventid,
    hoverinfo='x+y',
    mode='lines',
    line=dict(width=0.5,
              color='rgb(184, 247, 212)'),
    stackgroup='one',
    name = 'Black Liberation'
)

layout = go.Layout(
    xaxis=dict(
        title='Year',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
            
        ),
        tickfont=dict(
#             family='Old Standard TT, serif',
            size=14,
            color='black'
        ),
    ),
    yaxis=dict(
        title='Number of Acts of Terror',
        titlefont=dict(
            family='Arial, sans-serif',
            size=18,
            color='lightgrey',
        ),
    tickfont=dict(
#             family='Old Standard TT, serif',
            size=14,
            color='black'
        ),
    ),
    title=go.layout.Title(
        text='Number of Acts of Terror from Black Liberation, Anti-Arab, and White Extremist Groups, 1970-2017',
        xref='paper',
        x=0
    ),
)
data = [trace0, trace1, trace2]
fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='stacked-area-plot-hover', validate=False)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/12.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Treemap

# %%
df_usa.reset_index(inplace=True)

# %%
tree = df_usa[df_usa['iyear']>2002]

# %%
tree2 = tree[tree['gname']!='Unknown'].reset_index()

# %%
len(rects)
# Out:
# 39

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import squarify

x = 0.
y = 0.
width = 1000.
height = 600.

values = list(tree2.groupby('gname').count().eventid.values)

normed = squarify.normalize_sizes(values, width, height)
rects = squarify.squarify(normed, x, y, width, height)

# Choose colors from http://colorbrewer2.org/ under "Export"
color_brewer = ['rgb(247,252,253)','rgb(229,245,249)','rgb(204,236,230)','rgb(153,216,201)',
                 'rgb(102,194,164)','rgb(65,174,118)','rgb(35,139,69)','rgb(0,109,44)','rgb(0,68,27)',
                'rgb(247,252,253)','rgb(229,245,249)','rgb(204,236,230)','rgb(153,216,201)',
                 'rgb(102,194,164)','rgb(65,174,118)','rgb(35,139,69)','rgb(0,109,44)','rgb(0,68,27)',
                'rgb(247,252,253)','rgb(229,245,249)','rgb(204,236,230)','rgb(153,216,201)',
                 'rgb(102,194,164)','rgb(65,174,118)','rgb(35,139,69)','rgb(0,109,44)','rgb(0,68,27)',
               'rgb(247,252,253)','rgb(229,245,249)','rgb(204,236,230)','rgb(153,216,201)',
                'rgb(102,194,164)','rgb(65,174,118)','rgb(35,139,69)','rgb(0,109,44)','rgb(0,68,27)',
               'rgb(247,252,253)','rgb(229,245,249)','rgb(204,236,230)']
shapes = []
annotations = []
counter = 0

for r in rects:
    shapes.append( 
        dict(
            type = 'rect', 
            x0 = r['x'], 
            y0 = r['y'], 
            x1 = r['x']+r['dx'], 
            y1 = r['y']+r['dy'],
            line = dict( width = 2 ),
            fillcolor = color_brewer[counter]
        ) 
    )
    annotations.append(
        dict(
            x = r['x']+(r['dx']/2),
            y = r['y']+(r['dy']/2),
            text = tree2.groupby('gname').count().eventid.values[counter].astype(str),
            showarrow = False
        )
    )
    counter = counter + 1
    if counter >= len(color_brewer):
        counter = 0

# For hover text
trace0 = go.Scatter(
    x = [ r['x']+(r['dx']/2) for r in rects ], 
    y = [ r['y']+(r['dy']/2) for r in rects ],
    text = tree2.groupby('gname').count().index.values, 
    mode = 'text',
)
        
layout = dict(
    height=1000, 
    width=1000,
    xaxis=dict(showgrid=False,zeroline=False),
    yaxis=dict(showgrid=False,zeroline=False),
    shapes=shapes,
    annotations=annotations,
    hovermode='closest',
    title=go.layout.Title(
        text='Treemapping of Attacks in the US by Group, 2002-2017',
        xref='paper',
        x=0,
))

# With hovertext
figure = dict(data=[trace0], layout=layout)

# Without hovertext
# figure = dict(data=[Scatter()], layout=layout)

py.iplot(figure, filename='squarify-treemap')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pkdong/10.embed" height="1000px" width="1000px"></iframe>

# %% [markdown]
# attack type by region

# %%
import plotly

# %%
plotly.tools.set_credentials_file(username='pkdong', api_key='LlMkV2ITIGKKXR4K6qui')
